# %% [markdown]
# # Previsão de Aprovação de Emprestéstimos é Adequado
#
# O objetivo é claro: prever a variável binária Loan_Status (Aprovado ou Rejeitado). Isto é um problema de classificação ideal para treinar modelos como Random Forest, Regressão Logística ou SVM e analisar as suas métricas de forma aprofundada.
#
# ## Dataset
#
# O dataset elegido para este estudo foi **"Realistic Loan Approval Dataset | US & Canada""**, que contém características (features) que são cruciais no mundo real para a decisão de crédito, como:
#
# cibil_score (Credit Score): O atributo mais preditivo para crédito.
#
# income_annum: Rendimento Anual.
#
# loan_amount: Valor do Empréstimo.
#
# Atributos de Risco: no_of_dependents, loan_term, valor dos ativos.
#
# ### Necessário
#
# > dataset : Loan_approval_data_2025.csv.
# >
# > obtido em : https://www.kaggle.com/datasets/parthpatel2130/realistic-loan-approval-dataset-us-and-canada

# %%
# !pip install mlxtend
# !pip install catboost
# !pip install xgboost
import pandas as pd
import numpy as np

from catboost import CatBoostClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

from mlxtend.frequent_patterns import apriori, association_rules

import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb

import joblib

plt.rcParams['figure.figsize'] = (8, 5)
plt.rcParams['figure.dpi'] = 120

# %%
data_set_path = "./Data/Loan_approval_data_2025.csv"
df = pd.read_csv(data_set_path)
display(df.head())

# Debbug Extra
#print(df.columns)
#print(df.shape)
#print(df.info())
# Out:
#   customer_id  age occupation_status  years_employed  annual_income  \
# 0  CUST100000   40          Employed            17.2          25579
# 1  CUST100001   33          Employed             7.3          43087
# 2  CUST100002   42           Student             1.1          20840
# 3  CUST100003   53           Student             0.5          29147
# 4  CUST100004   32          Employed            12.5          63657
#
#    credit_score  credit_history_years  savings_assets  current_debt  \
# 0           692                   5.3             895         10820
# 1           627                   3.5             169         16550
# 2           689                   8.4              17          7852
# 3           692                   9.8            1480         11603
# 4           630                   7.2             209         12424
#
#    defaults_on_file  delinquencies_last_2yrs  derogatory_marks   product_type  \
# ...

# %% [markdown]
# ## Análise Exploratória de Dados (EDA)
#
# De forma a entender a estrutura, qualidade e as relações subjacentes do dataset, e tendo em conta que o DataFrame é tanto numérico padronizado e categórico $OHE$, a análise exploratória deve ser focada emd uas áreas principais, a Visão Geral e Análise Bivariada.

# %%
numeric_cols = [
    'age', 'years_employed', 'annual_income_log', 'credit_score', 
    'credit_history_years', 'savings_assets', 'current_debt', 
    'loan_amount_log', 'interest_rate', 'debt_to_income_ratio', 
    'loan_to_income_ratio', 'payment_to_income_ratio'
]

print("Informações do DataFrame:\n")
display(df.info())

print("\nValores Ausentes por Coluna:\n")
display(df.isnull().sum().sort_values(ascending=False).head())

status_counts = df['loan_status'].value_counts()
display(status_counts)
# Out:
# Informações do DataFrame:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customer_id              50000 non-null  object
#  1   age                      50000 non-null  int64
#  2   occupation_status        50000 non-null  object
#  3   years_employed           50000 non-null  float64
#  4   annual_income            50000 non-null  int64
#  5   credit_score             50000 non-null  int64
#  6   credit_history_years     50000 non-null  float64
#  7   savings_assets           50000 non-null  int64
#  8   current_debt             50000 non-null  int64
#  9   defaults_on_file         50000 non-null  int64
#  10  delinquencies_last_2yrs  50000 non-null  int64
#  11  derogatory_marks         50000 non-null  int64
#  12  product_type             50000 non-null  object
# ...

# %% [markdown]
# ### Análise Gráfica do Dataset
#
# Para confirmar a validade e o insight das Regras de Associação iremos apresentar um Count Plot do `loan_status` de forma a revelar o balanceamento da variável alvo, prevenindo modelos enviesados.
#
# Os Box Plots do `credit_scorte` e ànnual_income` vs `loan_status` identificam as variáveis numéricas mais preditivas.

# %%
df['age_group'] = pd.cut(
    df['age'],
    bins=[18,30,45,60, np.inf],
    labels = ['18-30_Jovem', '31-45_Adulto_Jovem', '46-60_Adulto', '60+_Senior'],
    right=False
)

# Visualização da Distribuição
plt.figure(figsize=(6, 4))
sns.countplot(x='loan_status', data=df)
plt.title('Balanceamento das Classes (Loan Status)')
plt.show()
# Box Plot para Credit Score vs. Loan Status
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.boxplot(x='loan_status', y='credit_score', data=df)
plt.title('Credit Score por Status do Empréstimo')

# Box Plot para Renda Anual vs. Loan Status
plt.subplot(1, 2, 2)
sns.boxplot(x='loan_status', y='annual_income', data=df)
plt.title('Renda Anual por Status do Empréstimo')

plt.tight_layout()
plt.show()

# Count Plot para Age Group vs. Loan Status (confirma a Regra de Associação!)
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='age_group', hue='loan_status')
plt.title('Distribuição de Loan Status por Grupo de Idade')
plt.show()

# %% [markdown]
# #### Interpetação Gráfica
#
# O gráfico do Balancemaneto das Classes, representa um gráfico `countplot`, para a variável alvo, loan_status. As contagens para `loan_status = 0` (Rejeitado) e `loan_status = 1` (Aprovado), são praticamente idênticas, ambas em torno de 21 000 a 22 000 ocorrências. Com este insight conseguimos perceber que o dataset é bastante balanceado, eleminando assim o modelo ML de ser enviesado em favor de uma classe e garante que o threshold usado seja um limiar justo e representativo.
#
# O gráfico das variáveis numéricas indicam que o `credit_score` é o preditor mais forte no dataset. Pessoas com scroes mais altos têm uma probabilidade muito maior de aprvação. Isto confirma a necessidade de discretizar esta variável e incluila na associação à priori. Também é possivel verificar que a `zanual_income` tem um impacto positivo na aprovação, mas é menos decisiva que o `credit_score`, verifica-se a existencia de outliars na renda o que sugere que temos entidades de alto patrimônio liquido ou grandes transações, que podem ser interpetados como valores reais, uma vez que estamos no contexto financeiro.
#
# Num caso de um empréstimo, e apesar de empréstimos de alto valor ocorrerem pontualmente no dataset, treinar um modelo sem estes valores, para o contexto financeiro pode fazer com que o modelo originado não consiga ter um previsão precisa nestes cenários.
#
# > Assim iremos manter os outliers mas aplicando um **Log-Transformação** na limpeza e reorganização do dataset antes da fase ML, cumprimindo assim distribuição, reduzindo o impacto destes valores pontuais sem os excluir
#
# No último gráfico apresenta de forma visual a quantidade de empréstimos por faxa étaria

# %% [markdown]
# ---

# %% [markdown]
# ## Regras de Associação à Priori
#
#
# De forma a percebemos qual antecedente, X implica um consequente, Y devemos determinar as métricas para usar num algoritmo à priori, onde a frequência onde X e Y aparecem juntos no conjunto de total de transações. Devemos também ter em conta a **confiança**, ou seja a probabilidade de um consquente estar associado ao antecedente.

# %%
# OHE
list_of_apriori_cols_completa = [
    # Colunas Discretizadas 
    "age_group",
    "income_group",      
    "credit_score_group",
    "loan_amount_group", 
    
    # Colunas com valores binários que vieram do OHE original
    "loan_status",
    "occupation_status",
    "product_type",      
    "loan_intent",
    
    # Colunas de Histórico de Crédito
    "defaults_on_file",
    "delinquencies_last_2yrs",
    "derogatory_marks"
]
    

df_apriori_ready = pd.get_dummies(df.loc[:, list_of_apriori_cols])

df_apriori_ready = df_apriori_ready.astype(bool)

display("DataFrame pronto para Apriori:\n", df_apriori_ready.head())
# Out:
# 'DataFrame pronto para Apriori:\n'
#    loan_status  occupation_status_Employed  occupation_status_Self-Employed  \
# 0         True                        True                            False
# 1        False                        True                            False
# 2         True                       False                            False
# 3         True                       False                            False
# 4         True                        True                            False
#
#    occupation_status_Student  age_group_18-30_Jovem  \
# 0                      False                  False
# 1                      False                  False
# 2                       True                  False
# 3                       True                  False
# 4                      False                  False
#
#    age_group_31-45_Adulto_Jovem  age_group_46-60_Adulto  age_group_60+_Senior
# 0                          True                   False                 False
# ...

# %%
freq_items = apriori(df_apriori_ready, min_support=0.05, use_colnames=True)

# Rules

rules = association_rules(freq_items, metric='confidence', min_threshold=0.6)
display(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
#                                           antecedents  \
# 0                                       (loan_status)
# 1                      (age_group_31-45_Adulto_Jovem)
# 2                            (age_group_46-60_Adulto)
# 3                             (age_group_18-30_Jovem)
# 4                      (age_group_31-45_Adulto_Jovem)
# 5                            (age_group_46-60_Adulto)
# 6                (loan_status, age_group_18-30_Jovem)
# 7         (loan_status, age_group_31-45_Adulto_Jovem)
# 8               (loan_status, age_group_46-60_Adulto)
# 9   (occupation_status_Employed, age_group_46-60_A...
# 10  (occupation_status_Self-Employed, age_group_31...
#
#                      consequents  support  confidence      lift
# 0   (occupation_status_Employed)  0.38018    0.690659  0.987474
# 1                  (loan_status)  0.27700    0.602934  1.095328
# 2                  (loan_status)  0.13708    0.742257  1.348430
# ...

# %% [markdown]
# ### Interpetação
#
# Para um threshold de 20%, que significa que a reunião dos dados tem que acontecer pelo menos 20% das vezes. No  caso acima usamos um threshold mais baixo para obtermos métricas mais abrangentes.
#
# A métrica `lift`, é mais importante, pois para além de nos dar insights, mede quanto a ocorrência do antecessor aumentea a probabilidade do consequente acontencer.
#
# > `Lift = 1`   - A ocorrência de $X$ e $Y$ é independente, ou seja a regra não apresenta valor.
# >
# > `Lift > 1`   - A ocorrência de $X$ e $Y$ é positivamente correlacionada. A regra dá-nos insights validos e é forte
# >
# > `Lift < 1`  - A ocorrência de $X$ e $Y$ é negativamente correlacionada.
# >
#
# A métrica `support`, apresenta a frequência com que um conjunto completo -  a reunião de X e Y - aparece em todas as transações do dataset.
#
# A métrica `confidence`, apresenta a fiabilidade da regra, por outras palavras é a probabilidade de Y ocorrer, dado que o X ocorreu.
#
# Dado este contexto das métricas apresentadas, as linhas 1 e 2 são as mais valiosoas uma vez que o lift > 1. As duas linhas mais fortes, em termos de impacto na concessão do empréstimo são:
#
# > **Linha 2**. Um sênior dentro da facha etária dos 46 aos 60 anos tem 34.8% mais chances de conseguir um empréstimo aprovado em relação à restante amostra
# >
# > **Linha 1**.  Um adulto dentro da facha etária dos 31 aos 45 tem 9.5% mais chance de conseguir um empréstimo aprovado comparado à restante amostra.
# >

# %% [markdown]
# # Limpeza Do Dataset
#
# Iremos limpar o dataset

# %%
cols_to_delete = ["customer_id"]
df_without_id =df.drop(columns = cols_to_delete)

# Verificação rápida para vermos se temos valor em falta
missing_values = df_without_id.isna().sum()
print(missing_values)
# Out:
# age                        0
# occupation_status          0
# years_employed             0
# annual_income              0
# credit_score               0
# credit_history_years       0
# savings_assets             0
# current_debt               0
# defaults_on_file           0
# delinquencies_last_2yrs    0
# derogatory_marks           0
# product_type               0
# loan_intent                0
# loan_amount                0
# interest_rate              0
# debt_to_income_ratio       0
# loan_to_income_ratio       0
# payment_to_income_ratio    0
# loan_status                0
# age_group                  0
# dtype: int64

# %% [markdown]
# ### One-Hot Enconding
#
# No dataset originial as váriveis product_type e loan_intent possuem valores em string, de forma a preparar os dados para machine learning devemos padronizar a informação. Neste caso usamos o One-Hot Enconding que é mais seguro uma vez que estas veriávies nao têm uma ordem inerente.
#
# Desta forma, as três colunas originais de texto `occupation_status, product_type, loan_intent` foram substituídas por várias novas colunas binárias (True ou False, que o modelo de ML trata como $1$ ou $0$).

# %%
categorical_cols = ['occupation_status', 'product_type', 'loan_intent', 'age_group']
cols_to_log_transform = ['annual_income', 'loan_amount']

df_new = pd.get_dummies(df_without_id , columns = categorical_cols, drop_first = True)

for col in cols_to_log_transform:
    df_new[f'{col}_log'] = np.log1p(df_new[col])

df_new = df_new.drop(columns=cols_to_log_transform)
display(df_new.head())
# Out:
#    age  years_employed  credit_score  credit_history_years  savings_assets  \
# 0   40            17.2           692                   5.3             895
# 1   33             7.3           627                   3.5             169
# 2   42             1.1           689                   8.4              17
# 3   53             0.5           692                   9.8            1480
# 4   32            12.5           630                   7.2             209
#
#    current_debt  defaults_on_file  delinquencies_last_2yrs  derogatory_marks  \
# 0         10820                 0                        0                 0
# 1         16550                 0                        1                 0
# 2          7852                 0                        0                 0
# 3         11603                 0                        1                 0
# 4         12424                 0                        0                 0
#
# ...

# %% [markdown]
# ### Normalização
#
# As colunas numéricas foram normalizadas com o StandardScaler(), que ajusta os dados para média zero e desvio padrão igual a um. Esta etapa é importante para algoritmos sensíveis a escalas, como clustering, PCA e métodos baseados em distância.
#
# Usamos o StandardScaler, para transformar os dados para estes terem a médica de 0 e um desvio padrão de 1. Assim indentificamos as colunas que devemos escalonar, estas estão contidas no `array -> numeric_cols`

# %%
scaler = StandardScaler()

df_new[numeric_cols] = scaler.fit_transform(df_new[numeric_cols])

#Debbug
print("\nDataFrame após Escalonamento:\n", df_new.head())
# Out:
# DataFrame após Escalonamento:
#          age  years_employed  credit_score  credit_history_years  \
# 0  0.453563        1.280229      0.747482             -0.397958
# 1 -0.176018       -0.020345     -0.256675             -0.647698
# 2  0.633444       -0.834846      0.701137              0.032151
# 3  1.622787       -0.913669      0.747482              0.226393
# 4 -0.265959        0.662785     -0.210330             -0.134343
#
#    savings_assets  current_debt  defaults_on_file  delinquencies_last_2yrs  \
# 0       -0.204093     -0.262046                 0                        0
# 1       -0.258959      0.170615                 0                        1
# 2       -0.270446     -0.486154                 0                        0
# 3       -0.159883     -0.202923                 0                        1
# 4       -0.255936     -0.140931                 0                        0
#
#    derogatory_marks  interest_rate  ...  loan_intent_Debt Consolidation  \
# ...

# %%
inertia = []

# k de 1 a 10
K_range = range(1, 11)

for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init='auto') 
    kmeans.fit(df_new)
    inertia.append(kmeans.inertia_)

plt.figure(figsize=(10, 6))
plt.plot(K_range, inertia, marker='o')
plt.title('Método do Cotovelo para K-Means')
plt.xlabel('Número de Clusters (K)')
plt.ylabel('Inércia (WCSS)')
plt.show()

# %% [markdown]
# ### Escolha do Cluster
#
# bjetivo não é minimizar o WCSS completamente o que aconteceria se $k$ fosse igual ao número total de pontos), mas sim encontrar o ponto de equilíbrio onde o aumento de $k$ não traz mais um benefício significativo.
#
# Tendo em analise os valores do grafico, o melhor valor de $k$, seria o **5** pois a partir deste valor o valor do WCSS desce abrutamente logo o nº de $k$ não traz mais valor pois adiciona complexidade sem melhorar significativamente a coesão dos grupos. Valores de $k$ inferiores a 5, é uma quantidade prematura para a analise.

# %% [markdown]
# ## Preparação para o Treino e Avaliação do Modelo
#
# Vamos separar os dados de treino e de teste, 70% do dataset será de treino e o restante de teste
#
# > `X - Features,` serao todas as colunas que o modelo usará para fazer a previsão
# >
# > `y - Target`, a variável que queremos prever, no caso loan_status

# %%
K_otimal = 5 

kmeans_model = KMeans(n_clusters=K_otimal, random_state=42, n_init='auto')
kmeans_model.fit(df_new)

df_new['Cluster'] = kmeans_model.labels_

X = df_new.drop('loan_status', axis=1)
y = df_new['loan_status']


X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size = 0.30, # 30%
    random_state = 42,
    stratify=y # Garante a propoção
)

# Debugg
print("\n DataFrame após K-Means")
display(df_new)

print(f"Número de Features (X): {X.shape[1]}")
print(f"Número de Observações (y): {y.shape[0]}")
print("-" * 30)
print(f"X_train (Treino): {X_train.shape}")
print(f"X_test (Teste):   {X_test.shape}")
print("-" * 30)
# Out:
#  DataFrame após K-Means
#             age  years_employed  credit_score  credit_history_years  \
# 0      0.453563        1.280229      0.747482             -0.397958
# 1     -0.176018       -0.020345     -0.256675             -0.647698
# 2      0.633444       -0.834846      0.701137              0.032151
# 3      1.622787       -0.913669      0.747482              0.226393
# 4     -0.265959        0.662785     -0.210330             -0.134343
# ...         ...             ...           ...                   ...
# 49995  0.003862       -0.414459     -1.137244              1.128234
# 49996 -0.086078       -0.401322      0.438511              0.614879
# 49997  0.543504       -0.348773      1.164594              0.268017
# 49998  0.273683       -0.926806     -0.163984             -0.952937
# 49999  1.622787        1.280229      0.793828              0.947866
#
#        savings_assets  current_debt  defaults_on_file  \
# 0           -0.204093     -0.262046                 0
# ...

# %% [markdown]
# # Treinamento do Modelo
#
# Para treinamos o modelo iremos exprimentar sobre vários modelos
#
# > `Decision Tree` - Tende a ser instável e propenso a overfitting nos dados de treino
# >
# > `Random Forest Classifier` - Modelo de ensemble. Combina centenas de Árvores de Decisão independentes e usa o voto maioritário para a previsão final
# >
# > `Regressão Logística` - Mode Linear simples. Tem a desvantagem de não conseguir capturar relações não lineares complexas, como o credict_score, annual_income e loan_status
# >

# %%
models = {
    'Decision Tree': DecisionTreeClassifier(random_state=42),
    'Random Forest': RandomForestClassifier(random_state=42),
    'Logistic Regression': LogisticRegression(random_state=42, max_iter=50000), # Valor alto para o modelo poder esta a vontade
    'XGBoost': xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42),
    'CatBoost': CatBoostClassifier( verbose=0, random_state=42, allow_writing_files=False)
}

results = {}

print('Inicio do Treinamento')

for name, model in models.items():
    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    conf_mat = confusion_matrix(y_test, y_pred)
    class_report = classification_report(y_test, y_pred, zero_division=0)
    acc = accuracy_score(y_test, y_pred)

    results[name] = {
        'Accuracy': acc,
        'Confusion Matrix': conf_mat,
        'Classification Report': class_report
    }

    print(f"\n {name} Concluído. Precisão: {acc: .4f}")
# Out:
# Inicio do Treinamento
#
#  Decision Tree Concluído. Precisão:  0.8697
#
#  Random Forest Concluído. Precisão:  0.9136
#
#  Logistic Regression Concluído. Precisão:  0.8699
# C:\Users\vasco\anaconda3\Lib\site-packages\xgboost\training.py:199: UserWarning: [15:51:59] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
#  XGBoost Concluído. Precisão:  0.9259
#
#  CatBoost Concluído. Precisão:  0.9315

# %% [markdown]
# **Erro nas interções** : Apesar do valor alto `max_iter` estar em 50 000 iterações o erro de convergência existe, significando que a natureza dos dados é fortemente não linear o que dificulta um modelo linear simples de convergir, no entanto em relação a testes anteriores com um valor de 1000 para 50 000 interção houve um ganho de 5% relativamente á precisão do modelo.

# %% [markdown]
# ## Apresentação das Matrizes Confusão

# %%
labels = ['Rejeitado - 0', 'Aprovado - 1']

def plot_confusion_matrix(cm, model_name):
    """ Apresenta as matrizes confusão, num heatmap """

    plt.figure(figsize=(6,5))

    sns.heatmap(
        cm, 
        annot=True, 
        fmt='d',          # Formata os números como inteiros
        cmap='Blues',     # Escolhe um esquema de cores
        xticklabels=labels, 
        yticklabels=labels
    )

    plt.title(f'Matriz de Confusão do Modelo : {model_name}')
    plt.ylabel('Valor Real (True Label)')
    plt.xlabel('Valor Previsto (Predicted Label)')
    plt.show()

for name, res in results.items():
    cm = res['Confusion Matrix']
    plot_confusion_matrix(cm, name)

    tn, fp, fn, tp = cm.ravel()
    
    print("-" * 50)
    print(f"Resultados para {name}:")
    print(f"FP (Risco: Aprovou mau cliente): {fp}")
    print(f"FN (Perda: Rejeitou bom cliente): {fn}")
# Out:
# --------------------------------------------------
# Resultados para Decision Tree:
# FP (Risco: Aprovou mau cliente): 965
# FN (Perda: Rejeitou bom cliente): 990
# --------------------------------------------------
# Resultados para Random Forest:
# FP (Risco: Aprovou mau cliente): 644
# FN (Perda: Rejeitou bom cliente): 652
# --------------------------------------------------
# Resultados para Logistic Regression:
# FP (Risco: Aprovou mau cliente): 1023
# FN (Perda: Rejeitou bom cliente): 928
# --------------------------------------------------
# Resultados para XGBoost:
# FP (Risco: Aprovou mau cliente): 588
# FN (Perda: Rejeitou bom cliente): 524
# --------------------------------------------------
# Resultados para CatBoost:
# FP (Risco: Aprovou mau cliente): 550
# FN (Perda: Rejeitou bom cliente): 477

# %% [markdown]
# #### Interpetação
#
# As matrizes de confusão mostram qual o modelo que atinge o equilíbrio ideal entre a maior precisão e a melhor gestão de risco, minimizando os erros mais dispendiosos no contexto de um empréstimo.
#
# O modelo CatBoost provou ser o mais robusto e eficaz, superando o Random Forest em todas as métricas críticas de gestão de risco.
#
# **Em suma**, em suma este modelo, demostrou uma superioridade significativa sobre os outros modelos, para além de apresentar uma precisão de ~93.13%.
#
# - Com 550 Falsos positivos, é o modelo que menos vezes aprova um cliente que realmente deveria ter sido rejeitado. Em contexto bancário, este erro traz mais prejuizos para a entidade bancária, pois leva a um prejuizo real.
#
# - Um FN, com 477 Falsos Negativos, é também o modelo que menos rejeita um cliente que realmente deveria ter sido aprovado, consequentemente dando à origem de uma perda de oportunidade de gerar **lucro**

# %% [markdown]
# # Importância das Variáveis

# %%
model_rf = models['CatBoost']
model_rf_dt = models['Decision Tree']

importances = model_rf.feature_importances_
importancesDt = model_rf_dt.feature_importances_

feature_names = X_train.columns
feature_importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
})

feature_names_dt = X_train.columns
feature_importance_df_dt = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importancesDt
})

feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
feature_importance_df_dt = feature_importance_df_dt.sort_values(by='Importance', ascending=False)

top_n = 5
plt.figure(figsize=(10,4))

sns.barplot(
    x='Importance',
    y='Feature',
    data=feature_importance_df_dt.head(top_n)
)

plt.title(f'Top {top_n} Variáveis Mais Importantes (Desicion Tree)')
plt.show()


sns.barplot(
    x='Importance',
    y='Feature',
    data=feature_importance_df.head(top_n)
)

plt.title(f'Top {top_n} Variáveis Mais Importantes (CatBoost)')
plt.show()

print("\n--- Top 10 Variáveis Mais Importantes ---")
print(feature_importance_df.head(top_n))
# Out:
# --- Top 10 Variáveis Mais Importantes ---
#                     Feature  Importance
# 10     debt_to_income_ratio   21.641843
# 2              credit_score   16.570940
# 6          defaults_on_file   10.669068
# 7   delinquencies_last_2yrs    8.237272
# 3      credit_history_years    6.098121

# %% [markdown]
# #### Interpretação
#
# Comparando o grafico de importâncias do melhor modelo registado - CatBost e um dos piores - DesicionTree é notável que o algoritmo não usou as mesmas variáveis, isto deve-se à diferença estrutural
#
# > - O Decision tree é um algoritmo greedy, constroi uma unica arvore e seleciona o split que melhor separa os dados em cada nó de cima para baixo.
# >
# > - Catboost, é um algoritmo de ensemble, ou seja Bosting. Constroi milheres de árvores sequencialmente, cada uma corrige os erros cometidos pelos conjunto anterior.
# >
#
# > Assim o peso das variáveis em cada algoritmo é diferente, num algoritmo greddy a frequência e eficácia com que uma variável é usadanos splits próximos do topo da árvore, já nos algoritmos de ensemble o peso a cada variável é dado pela contribuição média de uma vriável na redução do erro ao longo de todas as milhares de árvores. O modelo procura features que as árvores anteriores não conseguiram capturar.
#
#
# Esta análise de importância de features valida o modelo CatBoost, onde o modelo está a tomar decisões de aprovação com base em fatores economicamente e financeiramente relevantes, em vez de depender de correlações espúrias.
#
# A análise confirma que o Risco - medido por credit_score, debt_to_income_ratio e histórico é o motor principal da decisão de aprovação no seu dataset.
